# %% [markdown]
# # Analise dos Dados de Venda

# %%
# Importando o pandas
import pandas as pd

# %% [markdown]
# ## Importando os Dados

# %%
df = pd.read_excel('Report-consolidado.xlsx')

# %%
#Vizualização das primeiras linhas do Data Frame
df.head()
# Out:
#   Segmento      País    Produto  Qtde de Unidades Vendidas  Preço Unitário  \
# 0  Governo  Alemanha  Produto 1                     1321.0              20
# 1  Governo  Alemanha  Produto 1                     1513.0             350
# 2  Governo  Alemanha  Produto 2                     2146.0               7
# 3  Governo  Alemanha  Produto 3                     1006.0             350
# 4  Governo  Alemanha  Produto 3                     1513.0             350
#
#    Valor Total  Desconto  Valor Total c/ Desconto  Custo Total     Lucro  \
# 0      26420.0       0.0                  26420.0      14531.0   11889.0
# 1     529550.0       0.0                 529550.0     432718.0   96832.0
# 2      15022.0       0.0                  15022.0      10730.0    4292.0
# 3     352100.0       0.0                 352100.0     261560.0   90540.0
# 4     529550.0       0.0                 529550.0     393380.0  136170.0
#
#          Data       Mês   Ano
# 0  01/01/2019   Janeiro  2019
# ...

# %% [markdown]
# ## Verificando tipo de Dado

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Segmento                   700 non-null    object
#  1   País                       700 non-null    object
#  2   Produto                    700 non-null    object
#  3   Qtde de Unidades Vendidas  700 non-null    float64
#  4   Preço Unitário             700 non-null    int64
#  5   Valor Total                700 non-null    float64
#  6   Desconto                   700 non-null    float64
#  7   Valor Total c/ Desconto    700 non-null    float64
#  8   Custo Total                700 non-null    float64
#  9   Lucro                      700 non-null    float64
#  10  Data                       700 non-null    object
#  11  Mês                        700 non-null    object
#  12  Ano                        700 non-null    int64
# ...

# %% [markdown]
# ## Verificando quantidade de linhas

# %%
df.shape[0]
# Out:
# 700

# %% [markdown]
# ## Alterando o nome das Colunas no Data Frame

# %%
df.head()
# Out:
#   Segmento      País    Produto  Qtde de Unidades Vendidas  Preço Unitário  \
# 0  Governo  Alemanha  Produto 1                     1321.0              20
# 1  Governo  Alemanha  Produto 1                     1513.0             350
# 2  Governo  Alemanha  Produto 2                     2146.0               7
# 3  Governo  Alemanha  Produto 3                     1006.0             350
# 4  Governo  Alemanha  Produto 3                     1513.0             350
#
#    Valor Total  Desconto  Valor Total c/ Desconto  Custo Total     Lucro  \
# 0      26420.0       0.0                  26420.0      14531.0   11889.0
# 1     529550.0       0.0                 529550.0     432718.0   96832.0
# 2      15022.0       0.0                  15022.0      10730.0    4292.0
# 3     352100.0       0.0                 352100.0     261560.0   90540.0
# 4     529550.0       0.0                 529550.0     393380.0  136170.0
#
#          Data       Mês   Ano
# 0  01/01/2019   Janeiro  2019
# ...

# %%
colunas = ['segmento', 'pais', 'produto', 'qtd.', 'preco_unitario', 'valor_total', 'desconto', 'valor_total_desconto', 'custo_total', 'lucro', 'data', 'mes', 'ano']

# %%
# Verificação para ver se o numero da lista "colunas" é igual ao numero de colunas do Data Frame
len(colunas)
# Out:
# 13

# %%
df.columns = colunas

# %%
df.head()
# Out:
#   segmento      pais    produto    qtd.  preco_unitario  valor_total  \
# 0  Governo  Alemanha  Produto 1  1321.0              20      26420.0
# 1  Governo  Alemanha  Produto 1  1513.0             350     529550.0
# 2  Governo  Alemanha  Produto 2  2146.0               7      15022.0
# 3  Governo  Alemanha  Produto 3  1006.0             350     352100.0
# 4  Governo  Alemanha  Produto 3  1513.0             350     529550.0
#
#    desconto  valor_total_desconto  custo_total     lucro        data  \
# 0       0.0               26420.0      14531.0   11889.0  01/01/2019
# 1       0.0              529550.0     432718.0   96832.0  01/12/2019
# 2       0.0               15022.0      10730.0    4292.0  01/09/2019
# 3       0.0              352100.0     261560.0   90540.0  01/06/2019
# 4       0.0              529550.0     393380.0  136170.0  01/12/2019
#
#         mes   ano
# 0   Janeiro  2019
# 1  Dezembro  2019
# 2  Setembro  2019
# 3     Junho  2019
# 4  Dezembro  2019

# %% [markdown]
# ## Contagem Registro

# %%
df.segmento.value_counts()
# Out:
# segmento
# Governo              300
# Grandes empresas     100
# Médias empresas      100
# Pequenas empresas    100
# Vendas online        100
# Name: count, dtype: int64

# %%
df.produto.value_counts()
# Out:
# produto
# Produto 3    202
# Produto 4    109
# Produto 5    109
# Produto 6     94
# Produto 2     93
# Produto 1     93
# Name: count, dtype: int64

# %% [markdown]
# ## Analises Monetárias

# %%
df.describe().round(2)
# Out:
#           qtd.  preco_unitario  valor_total   desconto  valor_total_desconto  \
# count   700.00          700.00       700.00     700.00                700.00
# mean   1608.29          118.43    182759.43   13150.35             169609.07
# std     867.43          136.78    254262.28   22962.93             236726.35
# min     200.00            7.00      1799.00       0.00               1655.08
# 25%     905.00           12.00     17391.75     800.32              15928.00
# 50%    1542.50           20.00     37980.00    2585.25              35540.20
# 75%    2229.12          300.00    279025.00   15956.34             261077.50
# max    4492.50          350.00   1207500.00  149677.50            1159200.00
#
#        custo_total      lucro      ano
# count       700.00     700.00   700.00
# mean     147187.85   22421.22  2018.75
# std      205930.04   42282.73     0.43
# min         918.00  -71250.25  2018.00
# 25%        7538.00    2701.80  2018.75
# ...

# %% [markdown]
# ## Analise de Margem de Lucro

# %%
df.head()
# Out:
#   segmento      pais    produto    qtd.  preco_unitario  valor_total  \
# 0  Governo  Alemanha  Produto 1  1321.0              20      26420.0
# 1  Governo  Alemanha  Produto 1  1513.0             350     529550.0
# 2  Governo  Alemanha  Produto 2  2146.0               7      15022.0
# 3  Governo  Alemanha  Produto 3  1006.0             350     352100.0
# 4  Governo  Alemanha  Produto 3  1513.0             350     529550.0
#
#    desconto  valor_total_desconto  custo_total     lucro        data  \
# 0       0.0               26420.0      14531.0   11889.0  01/01/2019
# 1       0.0              529550.0     432718.0   96832.0  01/12/2019
# 2       0.0               15022.0      10730.0    4292.0  01/09/2019
# 3       0.0              352100.0     261560.0   90540.0  01/06/2019
# 4       0.0              529550.0     393380.0  136170.0  01/12/2019
#
#         mes   ano
# 0   Janeiro  2019
# 1  Dezembro  2019
# 2  Setembro  2019
# 3     Junho  2019
# 4  Dezembro  2019

# %% [markdown]
# ### Agrupando Dados

# %%
colunas = ['desconto', 'valor_total_desconto', 'custo_total', 'lucro']

# %% [markdown]
# #### Por Segmento

# %%
df_segmento = df.groupby('segmento')[colunas].sum().round(2)
df_segmento["margem_lucro"] = round((df_segmento['lucro'] / df_segmento['valor_total_desconto']) * 100,2)
df_segmento
# Out:
#                      desconto  valor_total_desconto  custo_total        lucro  \
# segmento
# Governo            3898805.83           52504260.67   41584282.5  10919978.17
# Grandes empresas   1457305.62           19611694.38   20568882.0   -957187.63
# Médias empresas     200786.92            2381883.08    1746100.0    635783.07
# Pequenas empresas  3513781.50           42427918.50   38641000.0   3786918.50
# Vendas online       134568.36            1800593.64     491233.8   1309359.84
#
#                    margem_lucro
# segmento
# Governo                   20.80
# Grandes empresas          -4.88
# Médias empresas           26.69
# Pequenas empresas          8.93
# Vendas online             72.72

# %% [markdown]
# #### Por Produto

# %%
df_produto = df.groupby('produto')[colunas].sum().round(2)
df_produto["margem_lucro"] = round((df_produto['lucro'] / df_produto['valor_total_desconto']) * 100,2)
df_produto
# Out:
#              desconto  valor_total_desconto  custo_total       lucro  \
# produto
# Produto 1  1122212.62           13815307.88   13187353.3   627954.58
# Produto 2  1159032.62           15390801.88   13276047.0  2114754.88
# Produto 3  2600518.05           33011143.95   28213706.0  4797437.95
# Produto 4  1576709.04           18250059.46   15944067.0  2305992.46
# Produto 5  1456612.48           20511921.02   17477313.0  3034608.02
# Produto 6  1290163.44           17747116.06   14933012.0  2814104.06
#
#            margem_lucro
# produto
# Produto 1          4.55
# Produto 2         13.74
# Produto 3         14.53
# Produto 4         12.64
# Produto 5         14.79
# Produto 6         15.86

# %% [markdown]
# #### Por País

# %%
df_pais = df.groupby('pais')[colunas].sum().round(2)
df_pais["margem_lucro"] = round((df_pais['lucro'] / df_pais['valor_total_desconto']) * 100,2)
df_pais
# Out:
#             desconto  valor_total_desconto  custo_total       lucro  \
# pais
# Alemanha  1416126.68           23505340.82   20094218.6  3411122.22
# Canadá    2044508.62           24887654.88   21575835.9  3311818.98
# Chile     1777582.89           20949352.11   18290422.3  2658929.81
# EUA       2239527.84           25029830.16   22194424.3  2835405.86
# França    1727502.22           24354172.28   20876597.2  3477575.08
#
#           margem_lucro
# pais
# Alemanha         14.51
# Canadá           13.31
# Chile            12.69
# EUA              11.33
# França           14.28
